# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=pd.DataFrame(np.random.randn(1000,4),index=pd.date_range('20100101',periods=1000),columns=list('ABCD'))

# %%
a
# Out:
#                    A         B         C         D
# 2010-01-01  1.008595 -0.204380  0.240909 -0.014298
# 2010-01-02 -0.323654 -0.261457  1.523014  1.590939
# 2010-01-03 -1.010230 -1.925800  1.222370  0.820427
# 2010-01-04 -1.523627 -0.024482 -0.595378 -0.855839
# 2010-01-05 -0.558002  1.369338  0.944622  1.550069
# 2010-01-06  0.961090 -0.269768  0.268795  0.390466
# 2010-01-07 -1.122450 -0.422467  2.314526  0.228581
# 2010-01-08  0.084495 -0.606030 -0.162167  2.092277
# 2010-01-09 -0.447373  0.189991  1.044645 -0.193784
# 2010-01-10 -0.756139 -1.330446 -0.578230  0.599915
# 2010-01-11 -0.811337  0.697982 -0.164639 -1.311104
# 2010-01-12  1.121050 -0.159924 -1.029513  0.441329
# 2010-01-13 -0.598477  0.917166  0.644720 -0.500897
# 2010-01-14  1.061106 -0.910057 -0.214282 -1.979760
# 2010-01-15 -1.619702 -0.783314  0.584142 -0.271408
# 2010-01-16  1.358331 -1.783024 -0.558357  0.687337
# 2010-01-17 -0.814284  0.690039 -0.203147 -1.691887
# ...

# %%
b=a.cumsum()
b.plot()
plt.show()

# %%
plt.savefig('../dataProcessing/')

# %%
plt.show()

# %%
b=a.cumsum()
b.plot()
plt.show()
plt.savefig('../dataProcessing/a.png')

# %%
b=a.cumsum()
b.plot()
plt.savefig('../dataProcessing/a.png')

# %%
plot_acf(b).show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b083b4cffc97> in <module>()
# ----> 1 plot_acf(b).show()
#
# NameError: name 'plot_acf' is not defined

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(b).show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b083b4cffc97> in <module>()
# ----> 1 plot_acf(b).show()
#
# NameError: name 'b' is not defined

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=pd.DataFrame(np.random.randn(1000,1),index=pd.date_range('20100101',periods=1000),columns='A')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-3d7ea729840d> in <module>()
# ----> 1 a=pd.DataFrame(np.random.randn(1000,1),index=pd.date_range('20100101',periods=1000),columns='A')
#
# /usr/local/lib/python2.7/site-packages/pandas-0.18.1-py2.7-macosx-10.11-x86_64.egg/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     253             else:
#     254                 mgr = self._init_ndarray(data, index, columns, dtype=dtype,
# --> 255                                          copy=copy)
#     256         elif isinstance(data, (list, types.GeneratorType)):
#     257             if isinstance(data, types.GeneratorType):
#
# /usr/local/lib/python2.7/site-packages/pandas-0.18.1-py2.7-macosx-10.11-x86_64.egg/pandas/core/frame.pyc in _init_ndarray(self, values, index, columns, dtype, copy)
# ...

# %%
a=pd.DataFrame(np.random.randn(1000,4),index=pd.date_range('20100101',periods=1000),columns=list('ABCD'))

# %%
b=a.cumsum()

# %%
b
# Out:
#                     A         B          C          D
# 2010-01-01  -0.175927  0.534364   0.249191  -0.697779
# 2010-01-02   0.444311 -0.309858   0.504206  -0.316003
# 2010-01-03  -1.502302 -0.834867  -0.067934  -0.244435
# 2010-01-04  -2.262087 -1.053962   0.593048  -1.452308
# 2010-01-05  -1.669458  0.842923  -0.030565  -0.363898
# 2010-01-06  -1.923499 -0.878346   0.657198  -0.717028
# 2010-01-07  -2.156314 -0.728019   0.755758  -3.321196
# 2010-01-08  -3.002877  0.212749   1.079196  -3.447207
# 2010-01-09  -1.709352  0.102556   1.634717  -3.456147
# 2010-01-10  -1.928084 -1.278582   1.695510  -4.674803
# 2010-01-11  -0.456342 -2.571894   2.897817  -4.495766
# 2010-01-12   1.924281 -3.618560   3.152476  -5.508261
# 2010-01-13   1.860281 -2.786182   3.705549  -6.154687
# 2010-01-14   3.132045 -3.423760   3.350924  -5.157926
# 2010-01-15   3.425743 -5.057187   2.000500  -4.154872
# 2010-01-16   3.696986 -4.732339   2.673733  -3.087735
# ...

# %%
plot_acf(b).show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b083b4cffc97> in <module>()
# ----> 1 plot_acf(b).show()
#
# /usr/local/lib/python2.7/site-packages/statsmodels/graphics/tsaplots.pyc in plot_acf(x, ax, lags, alpha, use_vlines, unbiased, fft, title, zero, **kwargs)
#     118     else:
#     119         acf_x, confint = acf(x, nlags=nlags, alpha=alpha, fft=fft,
# --> 120                              unbiased=unbiased)
#     121
#     122     _plot_corr(ax, title, acf_x, confint, lags, irregular, use_vlines, **kwargs)
#
# /usr/local/lib/python2.7/site-packages/statsmodels/tsa/stattools.pyc in acf(x, unbiased, nlags, qstat, fft, alpha, missing)
#     472     """
#     473     nobs = len(x)  # should this shrink for missing='drop' and NaNs in x?
# --> 474     avf = acovf(x, unbiased=unbiased, demean=True, fft=fft, missing=missing)
# ...

# %%
plot_acf(b[:,0]).show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-48cc0727f594> in <module>()
# ----> 1 plot_acf(b[:,0]).show()
#
# /usr/local/lib/python2.7/site-packages/pandas-0.18.1-py2.7-macosx-10.11-x86_64.egg/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas-0.18.1-py2.7-macosx-10.11-x86_64.egg/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
plot_acf(b['A']).show()
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
b['A']
# Out:
# 2010-01-01    -0.175927
# 2010-01-02     0.444311
# 2010-01-03    -1.502302
# 2010-01-04    -2.262087
# 2010-01-05    -1.669458
# 2010-01-06    -1.923499
# 2010-01-07    -2.156314
# 2010-01-08    -3.002877
# 2010-01-09    -1.709352
# 2010-01-10    -1.928084
# 2010-01-11    -0.456342
# 2010-01-12     1.924281
# 2010-01-13     1.860281
# 2010-01-14     3.132045
# 2010-01-15     3.425743
# 2010-01-16     3.696986
# 2010-01-17     5.447321
# 2010-01-18     5.883911
# 2010-01-19     5.627058
# 2010-01-20     6.728470
# 2010-01-21     8.384465
# 2010-01-22     9.926063
# 2010-01-23     9.639610
# 2010-01-24    10.835940
# 2010-01-25    11.285345
# 2010-01-26    11.081008
# 2010-01-27    12.332556
# 2010-01-28    12.634044
# 2010-01-29    13.821546
# 2010-01-30    13.041121
#                 ...
# 2012-08-28    34.362642
# 2012-08-29    35.634296
# 2012-08-30    35.377577
# 2012-08-31    34.302278
# 2012-09-01    34.548184
# 2012-09-02    34.269058
# 2012-09-03    33.798595
# ...

# %%
plot_acf(b['A'])

# %%
plot_acf(b['A']).savefig('../dataProcessing/a.png')

# %%
from statsmodels.tsa.stattools import adfuller as ADF

# %%
print(u'原始序列的ADF检验结果为：', ADF(b['A']))
# Out:
# (u'\u539f\u59cb\u5e8f\u5217\u7684ADF\u68c0\u9a8c\u7ed3\u679c\u4e3a\uff1a', (-2.9147610400389112, 0.043658218990442789, 1, 998, {'5%': -2.8644403834525169, '1%': -3.4369193380671001, '10%': -2.5683143032357298}, 2831.511804184951))

# %%
print('原始序列的ADF检验结果为：', ADF(b['A']))
# Out:
# ('\xe5\x8e\x9f\xe5\xa7\x8b\xe5\xba\x8f\xe5\x88\x97\xe7\x9a\x84ADF\xe6\xa3\x80\xe9\xaa\x8c\xe7\xbb\x93\xe6\x9e\x9c\xe4\xb8\xba\xef\xbc\x9a', (-2.9147610400389112, 0.043658218990442789, 1, 998, {'5%': -2.8644403834525169, '1%': -3.4369193380671001, '10%': -2.5683143032357298}, 2831.511804184951))

# %%
splitDataPath = '../dataProcessing/splitData/splitData.csv'

# %%
data = pd.read_csv(path)
data['starting_time'] = data['starting_time'].apply(lambda x: x.split(' ')[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-94e2d9955f0f> in <module>()
# ----> 1 data = pd.read_csv(path)
#       2 data['starting_time'] = data['starting_time'].apply(lambda x: x.split(' ')[0])
#
# NameError: name 'path' is not defined

# %%
data = pd.read_csv(splitDataPath)
data['starting_time'] = data['starting_time'].apply(lambda x: x.split(' ')[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-b231e0e3569d> in <module>()
# ----> 1 data = pd.read_csv(splitDataPath)
#       2 data['starting_time'] = data['starting_time'].apply(lambda x: x.split(' ')[0])
#
# NameError: name 'pd' is not defined

# %%
data
# Out:
#       intersection_id  tollgate_id  vehicle_id starting_time  \
# 0                   B            3     1065642    2016-07-19
# 1                   B            3     1047198    2016-07-19
# 2                   B            1     1086390    2016-07-19
# 3                   A            2     1071181    2016-07-19
# 4                   B            1     1065807    2016-07-19
# 5                   C            3     1072812    2016-07-19
# 6                   B            1     1014648    2016-07-19
# 7                   A            2     1063919    2016-07-19
# 8                   A            3     1064408    2016-07-19
# 9                   C            1     1056529    2016-07-19
# 10                  A            2     1002179    2016-07-19
# 11                  B            3     1056879    2016-07-19
# 12                  A            2     1004088    2016-07-19
# 13                  C            1     1063652    2016-07-19
# ...

# %%
dataSet = data.copy()
dataSet['travel_velocity'] = dataSet['travel_velocity'].apply(lambda x: np.array(x.split(';')).astype(float))
dataSet['travel_lane'] = dataSet['travel_lane'].apply(lambda x: np.array(x.split(';')).astype(float))
dataSet['travel_length'] = dataSet['travel_length'].apply(lambda x: np.array(x.split(';')).astype(float))

# %%
dataSet['total_velocity'][dataSet['total_velocity']>30]
# Out:
# 413      36.088475
# 512      35.403191
# 1046     40.721103
# 1538     31.464380
# 2232     30.967742
# 2245     36.519503
# 2384     31.143552
# 2399     30.023456
# 2521     37.677834
# 2923     42.167437
# 3211     37.411765
# 3261     38.240575
# 3345     41.334769
# 3609     36.192271
# 4058     32.196078
# 4625     40.151515
# 4657     38.309353
# 4984     39.970789
# 5847     30.648030
# 5851     38.412985
# 6195     40.677966
# 6196     35.921422
# 6600     34.620073
# 6933     36.777178
# 8036     36.781609
# 8401     37.101449
# 8660     40.961538
# 8685     32.665964
# 8751     36.021380
# 9296     39.650873
#            ...
# 84116    36.158192
# 84173    40.506329
# 84284    32.756632
# 84485    31.049563
# 84495    39.751553
# 84637    36.255319
# 84859    34.814143
# 84981    37.403189
# 85917    39.454094
# 85923    34.909091
# 85939    34.299517
# 86159    31.118314
# 86253    35.555556
# 86519    35.457064
# 86537    39.710445
# 87028    41.290323
# ...

# %%
dataSet['intersection_id']
# Out:
# 0        B
# 1        B
# 2        B
# 3        A
# 4        B
# 5        C
# 6        B
# 7        A
# 8        A
# 9        C
# 10       A
# 11       B
# 12       A
# 13       C
# 14       C
# 15       A
# 16       B
# 17       A
# 18       B
# 19       A
# 20       A
# 21       A
# 22       B
# 23       A
# 24       A
# 25       B
# 26       A
# 27       A
# 28       A
# 29       A
#         ..
# 88887    C
# 88888    C
# 88889    A
# 88890    A
# 88891    A
# 88892    B
# 88893    A
# 88894    C
# 88895    A
# 88896    B
# 88897    A
# 88898    A
# 88899    A
# 88900    C
# 88901    A
# 88902    A
# 88903    C
# 88904    A
# 88905    A
# 88906    A
# 88907    B
# 88908    A
# 88909    A
# 88910    A
# 88911    B
# 88912    A
# 88913    A
# 88914    A
# 88915    A
# 88916    A
# Name: intersection_id, dtype: object

# %%
dataSet.toarray()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-ddd5f223307d> in <module>()
# ----> 1 dataSet.toarray()
#
# /usr/local/lib/python2.7/site-packages/pandas-0.18.1-py2.7-macosx-10.11-x86_64.egg/pandas/core/generic.pyc in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'toarray'

# %%
dataSet.values
# Out:
# array([['B', 3, 1065642, ..., array([  78.,   58.,  121.,   23.,  197.]),
#         477, 6.73253352152],
#        ['B', 3, 1047198, ..., array([  78.,   58.,  121.,   23.,  197.]),
#         477, 3.2058606089099997],
#        ['B', 1, 1086390, ...,
#         array([  78.,   58.,  121.,   23.,  180.,   84.,  118.,   15.,  144.]),
#         821, 10.2933801404],
#        ...,
#        ['A', 3, 1003251, ...,
#         array([ 109.,   59.,   34.,   40.,    9.,  198.,  206.,  197.]),
#         852, 11.843202668900002],
#        ['A', 3, 1041002, ...,
#         array([ 109.,   59.,   34.,   40.,    9.,  198.,  206.,  197.]),
#         852, 6.429703418609999],
#        ['A', 3, 1017582, ...,
#         array([ 109.,   59.,   34.,   40.,    9.,  198.,  206.,  197.]),
#         852, 6.2017760955]], dtype=object)

# %%
a = dataSet.copy()

# %%
a['lane'] = a['travel_seq'].apply(lambda x: x.split(';'))

# %%
a['lane'] = a['line'].apply(lambda x: i.split('#')[0] for i in x)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-531dab968a63> in <module>()
# ----> 1 a['lane'] = a['line'].apply(lambda x: i.split('#')[0] for i in x)
#
# /usr/local/lib/python2.7/site-packages/pandas-0.18.1-py2.7-macosx-10.11-x86_64.egg/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas-0.18.1-py2.7-macosx-10.11-x86_64.egg/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
dataSet
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ed25f54fc492> in <module>()
# ----> 1 dataSet
#
# NameError: name 'dataSet' is not defined

# %%
dataSet = data.copy()
dataSet['travel_velocity'] = dataSet['travel_velocity'].apply(lambda x: np.array(x.split(';')).astype(float))
dataSet['travel_lane'] = dataSet['travel_lane'].apply(lambda x: np.array(x.split(';')).astype(float))
dataSet['travel_length'] = dataSet['travel_length'].apply(lambda x: np.array(x.split(';')).astype(float))
dataSet['travel_seq'] = dataSet['travel_seq'].apply(lambda x: x.split(';'))
    
dataSet.drop(['vehicle_id','total_velocity','total_length'],axis = 1,inplace = True)
dataSet
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-16f7ceb25920> in <module>()
# ----> 1 dataSet = data.copy()
#       2 dataSet['travel_velocity'] = dataSet['travel_velocity'].apply(lambda x: np.array(x.split(';')).astype(float))
#       3 dataSet['travel_lane'] = dataSet['travel_lane'].apply(lambda x: np.array(x.split(';')).astype(float))
#       4 dataSet['travel_length'] = dataSet['travel_length'].apply(lambda x: np.array(x.split(';')).astype(float))
#       5 dataSet['travel_seq'] = dataSet['travel_seq'].apply(lambda x: x.split(';'))
#
# NameError: name 'data' is not defined

# %%
result = []
for item in dataSet.values:
    for i,v in enumerate(item[3]):
        temp = []
        temp.extend(item[:2])
        temp.append(v.split('#')[0])
        temp.append(item[2])
        temp.extend(item[5:14])
        temp.append(item[14][i])
        temp.append(item[15][i])
        temp.append(item[16][i])
        result.append(result)
        print temp
label = ['intersection_id','tollgate_id','lane_id','starting_time','time_window','week','pressure','sea_pressure','wind_direction','wind_speed','temperature','rel_humidity','precipitation','travel_lane','travel_velocity','travel_length']
result = pd.DataFrame(result,columns = label)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ab639cc54e62> in <module>()
#       1 result = []
# ----> 2 for item in dataSet.values:
#       3     for i,v in enumerate(item[3]):
#       4         temp = []
#       5         temp.extend(item[:2])
#
# NameError: name 'dataSet' is not defined

# %%
import numpy as np
import pandas as pd

splitDataPath = '../dataProcessing/splitData/splitData.csv'

data = pd.read_csv(splitDataPath)
data['starting_time'] = data['starting_time'].apply(lambda x: x.split(' ')[0])

dataSet = data.copy()
dataSet['travel_velocity'] = dataSet['travel_velocity'].apply(lambda x: np.array(x.split(';')).astype(float))
dataSet['travel_lane'] = dataSet['travel_lane'].apply(lambda x: np.array(x.split(';')).astype(float))
dataSet['travel_length'] = dataSet['travel_length'].apply(lambda x: np.array(x.split(';')).astype(float))
dataSet['travel_seq'] = dataSet['travel_seq'].apply(lambda x: x.split(';'))
    
dataSet.drop(['vehicle_id','total_velocity','total_length'],axis = 1,inplace = True)

dataSet['starting_time'][dataSet['wind_speed'].isnull()]
# Out:
# 71415    2016-09-29
# 71416    2016-09-29
# 71417    2016-09-29
# 71418    2016-09-29
# 71419    2016-09-29
# 71420    2016-09-29
# 71421    2016-09-29
# 71422    2016-09-29
# 71423    2016-09-29
# 71424    2016-09-29
# 71425    2016-09-29
# 71426    2016-09-29
# 71427    2016-09-29
# 71428    2016-09-29
# 71429    2016-09-29
# 71430    2016-09-29
# 71431    2016-09-29
# 71432    2016-09-29
# 71433    2016-09-29
# 71434    2016-09-29
# 71435    2016-09-29
# 71436    2016-09-29
# 71437    2016-09-29
# 71438    2016-09-29
# 71439    2016-09-29
# 71440    2016-09-29
# 71441    2016-09-29
# 71442    2016-09-29
# 71443    2016-09-29
# 71444    2016-09-29
#             ...
# 77763    2016-10-10
# 77764    2016-10-10
# 77765    2016-10-10
# 77766    2016-10-10
# 77767    2016-10-10
# 77768    2016-10-10
# 77769    2016-10-10
# 77770    2016-10-10
# 77771    2016-10-10
# 77772    2016-10-10
# 77773    2016-10-10
# 77774    2016-10-10
# 77775    2016-10-10
# 77776    2016-10-10
# ...

# %%
import numpy as np
import pandas as pd

a = np.array([['2016-1-1',1,2.2],['2016-1-1',2,3.1],['2016-1-1',1,4.1],['2016-1-2',2,1.2],['2016-1-1',2,3.1],['2016-1-2',2,0.2]])
label = ['first','second','third']

b = pd.DataFrame(a,columns=label)
b[label[1:]] = b[label[1:]].apply(pd.to_numeric)
b['first'] = b['first'].apply(pd.to_datetime)
b[0:2]
# Out:
#        first  second  third
# 0 2016-01-01       1    2.2
# 1 2016-01-01       2    3.1

# %%
c = b.groupby(['first','second'])
c

# %%
c.mean().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 3 entries, (2016-01-01 00:00:00, 1) to (2016-01-02 00:00:00, 2)
# Data columns (total 1 columns):
# third    3 non-null float64
# dtypes: float64(1)
# memory usage: 48.0+ bytes

# %%
c = c.mean()
c.reset_index(inplace=True) 
c.set_index('first',inplace = True)

# %%
c
# Out:
#             second  third
# first
# 2016-01-01       1   3.15
# 2016-01-01       2   3.10
# 2016-01-02       2   0.70

# %%
c.columns[0]
# Out:
# 'second'

# %%
c
# Out:
#             second  third
# first
# 2016-01-01       1   3.15
# 2016-01-01       2   3.10
# 2016-01-02       2   0.70

# %%
c.iloc[0]
# Out:
# second    1.00
# third     3.15
# Name: 2016-01-01 00:00:00, dtype: float64

# %%
c.index
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-01', '2016-01-02'], dtype='datetime64[ns]', name=u'first', freq=None)

# %%
for i in c.index:
    print i
# Out:
# 2016-01-01 00:00:00
# 2016-01-01 00:00:00
# 2016-01-02 00:00:00

# %%
import numpy as np
import pandas as pd

d =pd.DataFrame(pd.date_range('20100101002000',periods=10,freq = '20min'),columns=['time'])
e = pd.DataFrame(np.random.randn(5,1),index=pd.date_range('20100101000000',periods=5,freq = '40min'),columns=list('A'))
print e['A']
f = pd.merge(d,e,how='left',left_on='time',right_index=True)
# Out:
# 2010-01-01 00:00:00    2.203988
# 2010-01-01 00:40:00    0.316649
# 2010-01-01 01:20:00    1.619755
# 2010-01-01 02:00:00    0.907531
# 2010-01-01 02:40:00    1.714572
# Freq: 40T, Name: A, dtype: float64

# %%
from datetime import datetime
d =pd.DataFrame(pd.date_range(start = '20160715',end = '20160716',freq = '20min'),columns=['time'])
d['time'] = d['time'].apply(lambda x: str(x))
def regularTime(s):
    time = datetime.strptime(s,"%Y-%m-%d %H:%M:%S")
    minute = time.minute
    time = time.replace(minute = (minute/20)*20,second = 0)
    return time.strftime("%Y-%m-%d %H:%M:%S")
d['pre'] = d['time'].apply(regularTime)
d
# Out:
#                    time                  pre
# 0   2016-07-15 00:00:00  2016-07-15 00:00:00
# 1   2016-07-15 00:20:00  2016-07-15 00:20:00
# 2   2016-07-15 00:40:00  2016-07-15 00:40:00
# 3   2016-07-15 01:00:00  2016-07-15 01:00:00
# 4   2016-07-15 01:20:00  2016-07-15 01:20:00
# 5   2016-07-15 01:40:00  2016-07-15 01:40:00
# 6   2016-07-15 02:00:00  2016-07-15 02:00:00
# 7   2016-07-15 02:20:00  2016-07-15 02:20:00
# 8   2016-07-15 02:40:00  2016-07-15 02:40:00
# 9   2016-07-15 03:00:00  2016-07-15 03:00:00
# 10  2016-07-15 03:20:00  2016-07-15 03:20:00
# 11  2016-07-15 03:40:00  2016-07-15 03:40:00
# 12  2016-07-15 04:00:00  2016-07-15 04:00:00
# 13  2016-07-15 04:20:00  2016-07-15 04:20:00
# 14  2016-07-15 04:40:00  2016-07-15 04:40:00
# 15  2016-07-15 05:00:00  2016-07-15 05:00:00
# 16  2016-07-15 05:20:00  2016-07-15 05:20:00
# 17  2016-07-15 05:40:00  2016-07-15 05:40:00
# 18  2016-07-15 06:00:00  2016-07-15 06:00:00
# 19  2016-07-15 06:20:00  2016-07-15 06:20:00
# ...

# %%
d
# Out:
#                   time
# 0  2016-07-15 00:00:00
# 1  2016-07-15 00:20:00
# 2  2016-07-15 00:40:00
# 3  2016-07-15 01:00:00
# 4  2016-07-15 01:20:00
# 5  2016-07-15 01:40:00
# 6  2016-07-15 02:00:00
# 7  2016-07-15 02:20:00
# 8  2016-07-15 02:40:00
# 9  2016-07-15 03:00:00
# 10 2016-07-15 03:20:00
# 11 2016-07-15 03:40:00
# 12 2016-07-15 04:00:00
# 13 2016-07-15 04:20:00
# 14 2016-07-15 04:40:00
# 15 2016-07-15 05:00:00
# 16 2016-07-15 05:20:00
# 17 2016-07-15 05:40:00
# 18 2016-07-15 06:00:00
# 19 2016-07-15 06:20:00
# 20 2016-07-15 06:40:00
# 21 2016-07-15 07:00:00
# 22 2016-07-15 07:20:00
# 23 2016-07-15 07:40:00
# 24 2016-07-15 08:00:00
# 25 2016-07-15 08:20:00
# 26 2016-07-15 08:40:00
# 27 2016-07-15 09:00:00
# 28 2016-07-15 09:20:00
# 29 2016-07-15 09:40:00
# ..                 ...
# 43 2016-07-15 14:20:00
# 44 2016-07-15 14:40:00
# 45 2016-07-15 15:00:00
# 46 2016-07-15 15:20:00
# 47 2016-07-15 15:40:00
# 48 2016-07-15 16:00:00
# 49 2016-07-15 16:20:00
# 50 2016-07-15 16:40:00
# ...

# %%
d
# Out:
#                  time
# 0 2010-01-01 00:00:00
# 1 2010-01-01 00:20:00
# 2 2010-01-01 00:40:00
# 3 2010-01-01 01:00:00
# 4 2010-01-01 01:20:00
# 5 2010-01-01 01:40:00
# 6 2010-01-01 02:00:00
# 7 2010-01-01 02:20:00
# 8 2010-01-01 02:40:00
# 9 2010-01-01 03:00:00

# %%
d.set_index('time',inplace = True)

# %%
d[0:3]
# Out:
# Empty DataFrame
# Columns: []
# Index: [2010-01-01 00:00:00, 2010-01-01 00:20:00, 2010-01-01 00:40:00]

# %%
d['pre'] = d.index

# %%
def regularTime(s):
    time = datetime.strptime(s,"%Y-%m-%d %H:%M:%S")
    minute = time.minute
    time.minute = (minute/20)*20
    time.second = 0
    return time.strftime("%Y-%m-%d %H:%M:%S")

d
# Out:
#                                     pre
# time
# 2010-01-01 00:00:00 2010-01-01 00:00:00
# 2010-01-01 00:20:00 2010-01-01 00:20:00
# 2010-01-01 00:40:00 2010-01-01 00:40:00
# 2010-01-01 01:00:00 2010-01-01 01:00:00
# 2010-01-01 01:20:00 2010-01-01 01:20:00
# 2010-01-01 01:40:00 2010-01-01 01:40:00
# 2010-01-01 02:00:00 2010-01-01 02:00:00
# 2010-01-01 02:20:00 2010-01-01 02:20:00
# 2010-01-01 02:40:00 2010-01-01 02:40:00
# 2010-01-01 03:00:00 2010-01-01 03:00:00

# %%
d.reindex()
# Out:
#                                     pre
# time
# 2010-01-01 00:00:00 2010-01-01 00:00:00
# 2010-01-01 00:20:00 2010-01-01 00:20:00
# 2010-01-01 00:40:00 2010-01-01 00:40:00
# 2010-01-01 01:00:00 2010-01-01 01:00:00
# 2010-01-01 01:20:00 2010-01-01 01:20:00
# 2010-01-01 01:40:00 2010-01-01 01:40:00
# 2010-01-01 02:00:00 2010-01-01 02:00:00
# 2010-01-01 02:20:00 2010-01-01 02:20:00
# 2010-01-01 02:40:00 2010-01-01 02:40:00
# 2010-01-01 03:00:00 2010-01-01 03:00:00

# %%
import numpy as np
import pandas as pd

a = [['2016-1-1',1],['2016-1-2',1],['2016-1-3',1],['2016-1-4',1]]
label1 = ['first','second']

b = pd.DataFrame(a,columns=label1)

c = [['2016-1-1',1],['2016-1-2',2],['2016-1-3',3],['2016-1-4',4],['2016-1-1',1],['2016-1-2',2],['2016-1-3',3],['2016-1-4',4]]
label2 = ['first','thrid']
d = pd.DataFrame(c,columns=label2)
f = pd.merge(b,d,how='outer',on = ['first'])
f.drop(7)
f
# Out:
#       first  second  thrid
# 0  2016-1-1       1      1
# 1  2016-1-1       1      1
# 2  2016-1-2       1      2
# 3  2016-1-2       1      2
# 4  2016-1-3       1      3
# 5  2016-1-3       1      3
# 6  2016-1-4       1      4
# 7  2016-1-4       1      4

# %%
c
# Out:
#    time  dsa
# 0     0    0
# 1     1    1
# 2     2    2
# 0     0    0
# 1     1    1
# 2     3    3

# %%
import numpy as np
import pandas as pd

d =pd.DataFrame(pd.date_range('20100101002000',periods=10,freq = '20min'),columns=['time'])
d
# Out:
#                  time
# 0 2010-01-01 00:20:00
# 1 2010-01-01 00:40:00
# 2 2010-01-01 01:00:00
# 3 2010-01-01 01:20:00
# 4 2010-01-01 01:40:00
# 5 2010-01-01 02:00:00
# 6 2010-01-01 02:20:00
# 7 2010-01-01 02:40:00
# 8 2010-01-01 03:00:00
# 9 2010-01-01 03:20:00

# %%
from statsmodels.tsa.arima_process import arma_generate_sample
import statsmodels.api as sm
import numpy as np
arparams = np.array([.75, -.25])
maparams = np.array([.65, .35])
arparams = np.r_[1, -arparams]
maparam = np.r_[1, maparams]
nobs = 250
np.random.seed(2014)
y = arma_generate_sample(arparams, maparams, nobs)
res = sm.tsa.arma_order_select_ic(y, ic=['aic', 'bic'], trend='nc')
print type(y)
res.aic_min_order
res.bic_min_order
# Out:
# <type 'numpy.ndarray'>
# (1, 2)

# %%
# Out:
#                      Unnamed: 0                time  travel_velocity  \
# time
# 2016-07-19 00:00:00           0 2016-07-19 00:00:00         8.592593
# 2016-07-19 00:20:00           5 2016-07-19 00:20:00        14.073288
# 2016-07-19 00:40:00          21 2016-07-19 00:40:00         4.700162
# 2016-07-19 01:20:00          36 2016-07-19 01:20:00         6.203209
# 2016-07-19 01:40:00          60 2016-07-19 01:40:00         7.815188
# 2016-07-19 02:00:00          81 2016-07-19 02:00:00        12.775330
# 2016-07-19 02:40:00          96 2016-07-19 02:40:00         6.002074
# 2016-07-19 03:40:00         121 2016-07-19 03:40:00        12.429168
# 2016-07-19 04:00:00         132 2016-07-19 04:00:00         8.898631
# 2016-07-19 04:20:00         143 2016-07-19 04:20:00        11.189283
# 2016-07-19 04:40:00         159 2016-07-19 04:40:00        11.765142
# 2016-07-19 05:00:00         183 2016-07-19 05:00:00         6.035380
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                  time
# 0 2016-07-19 00:00:00
# 1 2016-07-19 00:20:00
# 2 2016-07-19 00:40:00
# 0 2016-07-19 00:00:00
# 1 2016-07-19 00:20:00
# 2 2016-07-19 00:40:00

# %%
import numpy as np
import pandas as pd
import pyflux as pf
from datetime import datetime
import matplotlib.pyplot as plt

data = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/datasets/sunspot.year.csv')
data.index = data['time'].values

model = pf.ARIMA(data=data, ar=4, ma=4, target='sunspot.year', family=pf.Normal())
model.fit("MLE")
model.plot_fit(figsize=(15,10))
model.predict_is(50,True,"MLE")
# Out:
#           Series
# 1939   89.985852
# 1940   60.848128
# 1941   43.007761
# 1942   27.502189
# 1943   21.731168
# 1944   15.362818
# 1945   17.101811
# 1946   52.428598
# 1947  115.927698
# 1948  158.397737
# 1949  103.945633
# 1950  103.992176
# 1951   36.820952
# 1952   39.450468
# 1953   12.928671
# 1954    3.119399
# 1955   18.050874
# 1956   56.094359
# 1957  181.526560
# 1958  179.653299
# 1959  143.580060
# 1960  108.080124
# 1961   49.062317
# 1962    6.464400
# 1963   19.711271
# 1964   24.722477
# 1965   11.226058
# 1966   32.245299
# 1967   67.141078
# 1968  109.744034
# 1969   98.913477
# 1970   87.114963
# 1971   83.977127
# 1972   30.931093
# 1973   57.799578
# 1974   19.710937
# 1975   30.248033
# 1976   18.796546
# 1977   15.292574
# 1978   48.399528
# 1979  113.912171
# 1980  166.408856
# 1981  123.165233
# 1982  103.571359
# 1983   72.324367
# 1984   19.495637
# 1985   27.115795
# 1986    4.871224
# 1987   18.542243
# 1988   48.009222

# %%
import numpy as np
import pandas as pd
arimaPicturePath = '../dataProcessing/arimaPicture/'
data = pd.read_csv(arimaPicturePath+'result.csv')

data['time_window'] = data['time_window'].apply(lambda x: x.split(']')[0]+')')

data
# data.to_csv(arimaPicturePath+'result.csv',index=False)
# Out:
#     intersection  tollgate                                 time_window  \
# 0              A         3  [2016-10-18 08:00:00,2016-10-18 08:20:00))
# 1              A         3  [2016-10-18 08:20:00,2016-10-18 08:40:00))
# 2              A         3  [2016-10-18 08:40:00,2016-10-18 09:00:00))
# 3              A         3  [2016-10-18 09:00:00,2016-10-18 09:20:00))
# 4              A         3  [2016-10-18 09:20:00,2016-10-18 09:40:00))
# 5              A         3  [2016-10-18 09:40:00,2016-10-18 10:00:00))
# 6              A         3  [2016-10-18 17:00:00,2016-10-18 17:20:00))
# 7              A         3  [2016-10-18 17:20:00,2016-10-18 17:40:00))
# 8              A         3  [2016-10-18 17:40:00,2016-10-18 18:00:00))
# 9              A         3  [2016-10-18 18:00:00,2016-10-18 18:20:00))
# 10             A         3  [2016-10-18 18:20:00,2016-10-18 18:40:00))
# 11             A         3  [2016-10-18 18:40:00,2016-10-18 19:00:00))
# ...

# %%
from sklearn.svm import SVR
import numpy as np
n_samples, n_features = 10, 5
np.random.seed(0)
y = np.random.randn(n_samples)
X = np.random.randn(n_samples, n_features)
clf = SVR(C=1.0, epsilon=0.2)
clf.fit(X, y)
clf.predict(X)
# Out:
# array([ 0.89267763,  0.60015715,  0.98206621,  1.85535147,  0.92760639,
#         0.37993472,  1.02794306,  0.0486428 ,  0.32927924,  0.34111871])

# %%
import numpy as np
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
import pyflux as pf
import csv 
import matplotlib.pyplot as plt
from datetime import datetime
import os 

import pyflux as pf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
 
plt.figure(figsize=(24, 12))
  
# A Noisy sine wave signal
angles = np.linspace(-np.pi, np.pi*10, 100)
sine_wave = np.sin (angles) + np.random.sample(len(angles))*0.30
  
#Let's plot our noisy sine wave
plt.plot(angles, sine_wave)
plt.show()
  
#put it in a Pandas frame
df = pd.DataFrame({ 'SineWave' : sine_wave})
  
#ARIMA Model
model = pf.ARIMA(data=df,ar=6,ma=6,integ=0,target='SineWave')
  
x = model.fit("MLE") #Maximum Likelihood Estimate Inference
  
x.summary()
  
# Plot 40% of past values and plot same amount of forecasted data
model.plot_predict(h=int(0.40*len(angles)),past_values=int(0.40*len(angles)),figsize=(24,12))

def test_stationarity(timeseries):
    print timeseries
    dftest = adfuller(timeseries, autolag='AIC')
    print dftest
    return dftest[1]

def bestDiff(df, maxdiff = 8):
    p_set = {}
    for i in range(0, maxdiff):
        temp = df.copy() #每次循环前，重置
        if i == 0:
            temp['diff'] = temp[temp.columns[1]]
        else:
            temp['diff'] = temp[temp.columns[1]].diff(i)
            temp = temp.drop(temp.iloc[:i].index) #差分后，前几行的数据会变成nan，所以删掉
        pvalue = test_stationarity(temp['diff'])
        p_set[i] = pvalue
        p_df = pd.DataFrame.from_dict(p_set, orient="index")
        p_df.columns = ['p_value']
    i = 0
    while i < len(p_df):
        if p_df['p_value'][i]<0.01:
            bestdiff = i
            break
        i += 1
    return bestdiff

def produce_diffed_timeseries(df, diffn):
    if diffn != 0:
        df['diff'] = df[df.columns[1]].apply(lambda x:float(x)).diff(diffn)
    else:
        df['diff'] = df[df.columns[1]].apply(lambda x:float(x))
    df.dropna(inplace=True) #差分之后的nan去掉
    return df

def choose_order(ts, maxar, maxma):
    print 'choose order'
    print ts
    order = sm.tsa.arma_order_select_ic(ts, maxar, maxma, ic=['aic', 'bic', 'hqic'])
    print 'finish'
    return order.bic_min_order

def predict_recover(ts, df, diffn):
    if diffn != 0:
        ts.iloc[0] = ts.iloc[0]+df['log'][-diffn]
        ts = ts.cumsum()
    ts = np.exp(ts)
#    ts.dropna(inplace=True)
    print('还原完成')
    return ts


def run_aram(df, maxar, maxma, test_size):
    
    train = df.dropna()
    train['log'] = np.log(train[train.columns[0]])
    print train
    diffn = 0
    if test_stationarity(train[train.columns[1]]) < 0.01:
        train['diff'] = train['log']
        print('平稳，不需要差分')
    else:
        diffn = best_diff(train, maxdiff = 8)
        train = produce_diffed_timeseries(train, diffn)
        print('差分阶数为'+str(diffn)+'，已完成差分')
    print('开始进行ARMA拟合')
    order = choose_order(train[train.columns[2]], maxar, maxma)
    print('模型的阶数为：'+str(order))
    _ar = order[0]
    _ma = order[1]
    model = pf.ARIMA(data=train, ar=_ar, ma=_ma,integ=diffn,target='diff')
    model.fit("MLE")
    test_predict = model.predict(test_size)
    test_predict.columns = ['travel_velocity']
    test_predict.index = test_predict.index + pd.DateOffset(minutes = test_size*20)
    test_predict = predict_recover(test_predict, train, diffn)
    return test_predict

# %%
t = range(1,200)
t = np.array(t)
s = np.sin(t)+1 
p = pd.DataFrame(s,columns=['sin'])
run_aram(p,5,5,10)
# Out:
#           sin        log
# 0    1.841471   0.610565
# 1    1.909297   0.646735
# 2    1.141120   0.132010
# 3    0.243198  -1.413881
# 4    0.041076  -3.192338
# 5    0.720585  -0.327693
# 6    1.656987   0.505001
# 7    1.989358   0.687812
# 8    1.412118   0.345091
# 9    0.455979  -0.785309
# 10   0.000010 -11.533797
# 11   0.463427  -0.769106
# 12   1.420167   0.350774
# 13   1.990607   0.688440
# 14   1.650288   0.500950
# 15   0.712097  -0.339542
# 16   0.038603  -3.254438
# 17   0.249013  -1.390251
# 18   1.149877   0.139655
# 19   1.912945   0.648644
# 20   1.836656   0.607946
# 21   0.991149  -0.008891
# 22   0.153780  -1.872235
# 23   0.094422  -2.359985
# 24   0.867648  -0.141969
# 25   1.762558   0.566766
# 26   1.956376   0.671094
# 27   1.270906   0.239730
# 28   0.336366  -1.089555
# 29   0.011968  -4.425487
# ..        ...        ...
# 169  1.346649   0.297620
# 170  1.976591   0.681374
# 171  1.708659   0.535709
# 172  0.789189  -0.236749
# 173  0.063538  -2.756117
# ...

# %%
import pyflux as pf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import statsmodels.api as sm
    
def test_stationarity(timeseries):
    dftest = adfuller(timeseries, autolag='AIC')
    print dftest
    return dftest[1]

def best_diff(df, maxdiff = 8):
    p_set = {}
    for i in range(0, maxdiff):
        temp = df.copy() #每次循环前，重置
        if i == 0:
            temp['diff'] = temp[temp.columns[0]]
        else:
            temp['diff'] = temp[temp.columns[0]].diff(i)
            temp = temp.drop(temp.iloc[:i].index) #差分后，前几行的数据会变成nan，所以删掉
        pvalue = test_stationarity(temp['diff'])
        p_set[i] = pvalue
        p_df = pd.DataFrame.from_dict(p_set, orient="index")
        p_df.columns = ['p_value']
    i = 0
    while i < len(p_df):
        if p_df['p_value'][i]<0.01:
            bestdiff = i
            break
        i += 1
    return bestdiff

def produce_diffed_timeseries(df, diffn):
    if diffn != 0:
        df['diff'] = df[df.columns[0]].apply(lambda x:float(x)).diff(diffn)
    else:
        df['diff'] = df[df.columns[0]].apply(lambda x:float(x))
    df.dropna(inplace=True) #差分之后的nan去掉
    return df

def choose_order(ts, maxar, maxma):
    print 'choose order'
    order = sm.tsa.arma_order_select_ic(ts, maxar, maxma, ic=['aic', 'bic', 'hqic'],trend='c', fit_kw=dict(method='css'))
    print 'finish'
    return order.bic_min_order

def predict_recover(ts, df, diffn):
    if diffn != 0:
        ts.iloc[0] = ts.iloc[0]+df[df.columns[0]][-diffn]
        ts = ts.cumsum()
#    ts.dropna(inplace=True)
    print('还原完成')
    return ts

def handleWeaInflu(data,isTest = False):
    label = ['travel_velocity']
    # some day (9-28,10-10) lack the information of weather
    handleData = data.copy()

    handleData = handleData['travel_velocity'][handleData['travel_velocity']<30].to_frame()
    
    # ga
    if not isTest:
        time=pd.DataFrame(pd.date_range(start = '20160719000000',end = '20161017234000',freq = '20min'),columns=['time'])
    else:
        temp1 = pd.DataFrame(pd.date_range(start = '20161018060000',end = '20161018074000',freq = '20min'),columns=['time'])
        temp2 = pd.DataFrame(pd.date_range(start = '20161018150000',end = '20161018164000',freq = '20min'),columns=['time'])
        times = []
        times.append(temp1.copy())
        times.append(temp2.copy())
        for i in range(6):
            temp1['time'] = temp1['time'] + pd.DateOffset(days = 1)
            temp2['time'] = temp2['time'] + pd.DateOffset(days = 1)
            times.append(temp1.copy())
            times.append(temp2.copy())
        
        time = pd.concat(times)
        time.reset_index()
        2
        
    result = pd.merge(time,handleData,how='left',left_on='time',right_index=True)
    result.set_index('time',inplace = True)
    result = result.interpolate()
    result.fillna(method = 'pad')

    return result


#put it in a Pandas frame
df = pd.read_csv('../dataProcessing/splitByLaneData/lane_106.csv')
print df.tail()
df['time'] = df['time'].apply(pd.to_datetime)
df.set_index('time',inplace = True)
    
df = handleWeaInflu(df).dropna()
test = df[-36:]
df = df[-144:]


diffn = 0
# train = produce_diffed_timeseries(train, 1)
# train.plot(figsize = (200,10))
# plt.show()
if test_stationarity(df[df.columns[0]]) < 0.01:
    df['diff'] = df[df.columns[0]]
    print('平稳')
else:
    diffn = best_diff(df, maxdiff = 8)
    df = produce_diffed_timeseries(df, diffn)
    print('差分阶数为'+str(diffn)+'，已完成差分')
print('开始进行ARMA拟合')


order = choose_order(df[df.columns[0]], 10, 6)
print('模型的阶数为：'+str(order))
_ar = order[0]
_ma = order[1]


# print df
# model = sm.tsa.ARIMA(df['diff'],order = (_ar,diffn,_ma)).fit()

# predict = model.predict(12,48)
model = pf.ARIMA(data=df, ar=_ar, ma=_ma, integ=diffn,target='diff',family=pf.Normal())
model.fit("MLE")
predict = model.predict(12)
# predict = model.predict(6480, 6602)
predict.index = test.index[:12]+pd.DateOffset(minutes = 36*20)
test_predict = predict_recover(predict, df, diffn)
print test_predict
fig, ax = plt.subplots(figsize=(12, 8))
ax = test.plot(ax=ax)
test_predict.plot(ax=ax)
plt.show()
# Out:
#       Unnamed: 0                 time  travel_velocity  pressure  \
# 4241      121290  2016-10-17 21:00:00         8.875740    1013.9
# 4242      121314  2016-10-17 21:20:00         9.868421    1013.9
# 4243      121358  2016-10-17 22:20:00        11.873790    1013.9
# 4244      121401  2016-10-17 23:00:00        11.718750    1013.9
# 4245      121425  2016-10-17 23:20:00         8.990095    1013.9
#
#       sea_pressure  wind_direction  wind_speed  temperature  rel_humidity  \
# 4241        1018.9           322.0         2.5         19.3          90.0
# 4242        1018.9           322.0         2.5         19.3          90.0
# 4243        1018.9           322.0         2.5         19.3          90.0
# 4244        1018.9           322.0         2.5         19.3          90.0
# 4245        1018.9           322.0         2.5         19.3          90.0
#
#       precipitation
# 4241            0.0
# 4242            0.0
# 4243            0.0
# 4244            0.0
# 4245            0.0
# ...

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import statsmodels.api as sm


def choose_order(ts, maxar, maxma):
    print 'choose order'
    order = sm.tsa.arma_order_select_ic(ts, maxar, maxma, ic=['aic', 'bic', 'hqic'],trend='c', fit_kw=dict(method='css'))
    print 'finish'
    return order.bic_min_order


def handleWeaInflu(data,isTest = False):
    label = ['travel_velocity']
    # some day (9-28,10-10) lack the information of weather
    handleData = data.copy()

    handleData = handleData['travel_velocity'][handleData['travel_velocity']<30].to_frame()
    
    # ga
    if not isTest:
        time=pd.DataFrame(pd.date_range(start = '20160719000000',end = '20161017234000',freq = '20min'),columns=['time'])
    else:
        temp1 = pd.DataFrame(pd.date_range(start = '20161018060000',end = '20161018074000',freq = '20min'),columns=['time'])
        temp2 = pd.DataFrame(pd.date_range(start = '20161018150000',end = '20161018164000',freq = '20min'),columns=['time'])
        times = []
        times.append(temp1.copy())
        times.append(temp2.copy())
        for i in range(6):
            temp1['time'] = temp1['time'] + pd.DateOffset(days = 1)
            temp2['time'] = temp2['time'] + pd.DateOffset(days = 1)
            times.append(temp1.copy())
            times.append(temp2.copy())
        
        time = pd.concat(times)
        time.reset_index()
        
        
    result = pd.merge(time,handleData,how='left',left_on='time',right_index=True)
    result.set_index('time',inplace = True)
    result = result.interpolate()
    result.fillna(method = 'pad')

    return result


df = pd.read_csv('../dataProcessing/splitByLaneData/lane_102.csv')

df['time'] = df['time'].apply(pd.to_datetime)
df.set_index('time',inplace = True)

df = handleWeaInflu(df).dropna()
df['log'] = np.log(df['travel_velocity'])
df['diff'] = df['travel_velocity'].diff().interpolate()
df['diff'][df['diff'].isnull()] = 0


decomposition = seasonal_decompose(df['diff'].to_frame(), model="additive", freq=72)

trend = decomposition.trend.dropna()
seasonal = decomposition.seasonal
residual = decomposition.resid.dropna()

# print trend.info()
# print seasonal.info()
# print residual.info()

# trend.plot(figsize = (200,10))
# seasonal.plot(figsize = (200,10))
# residual.plot(figsize = (200,10))
# plt.show()


dftest = adfuller(residual['diff'], autolag='AIC')
print dftest

# dftest = adfuller(seasonal['diff'], autolag='AIC')
# print dftest


# dftest = adfuller(residual['diff'], autolag='AIC')
# print dftest

diffn = 1
order = choose_order(residual[residual.columns[0]], 50, 20)
print('模型的阶数为：'+str(order))
_ar = order[0]
_ma = order[1]


model = sm.tsa.ARIMA(residual['diff'],order = (_ar,diffn,_ma)).fit()

predict = model.predict(6470,6552)
predict = pd.DataFrame(predict[-72:],columns=['diff'])
predict.index = residual.index[-72:]+pd.DateOffset(minutes = 72*20)

print predict
fig, ax = plt.subplots(figsize=(12, 8))
ax = residual[-72:].plot(ax=ax)
predict.plot(ax=ax)
plt.show()
# Out:
# (-23.96640132603191, 0.0, 35, 6442, {'5%': -2.8619887671862987, '1%': -3.4313655087902184, '10%': -2.5670088755114415}, 28647.516499854406)
# choose order
# /usr/local/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# /usr/local/lib/python2.7/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ...

# %%
import pandas as pd
import numpy as np
from fbprophet import Prophet

from statsmodels.tsa.seasonal import seasonal_decompose

import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import statsmodels.api as sm


df = pd.read_csv('../dataProcessing/splitByLaneData/lane_100.csv')

df['time'] = df['time'].apply(pd.to_datetime)
df.set_index('time',inplace = True)

df = handleWeaInflu(df).dropna()
df['log'] = np.log(df['travel_velocity'])
df['diff'] = df['travel_velocity'].diff().interpolate()
df['diff'][df['diff'].isnull()] = 0


decomposition = seasonal_decompose(df['travel_velocity'].to_frame(), model="additive", freq=72)

trend = decomposition.trend.dropna()
seasonal = decomposition.seasonal
residual = decomposition.resid.dropna()

trend['']
m = Prophet(yearly_seasonality=False,weekly_seasonality = True)
m.fit(df);

future = m.make_future_dataframe(periods=72,freq = '20min')
print future.tail()

forecast = m.predict(future)
print forecast.tail()

m.plot(forecast);
# m.plot_components(forecast)
plt.show()
# Out:
# Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
#                       ds
# 5236 2016-10-18 22:00:00
# 5237 2016-10-18 22:20:00
# 5238 2016-10-18 22:40:00
# 5239 2016-10-18 23:00:00
# 5240 2016-10-18 23:20:00
#                       ds         t     trend  seasonal_lower  seasonal_upper  \
# 5236 2016-10-18 22:00:00  1.010382  9.636813        0.113393        0.113393
# 5237 2016-10-18 22:20:00  1.010534  9.637125        0.113393        0.113393
# 5238 2016-10-18 22:40:00  1.010687  9.637437        0.113393        0.113393
# 5239 2016-10-18 23:00:00  1.010840  9.637749        0.113393        0.113393
# 5240 2016-10-18 23:20:00  1.010992  9.638061        0.113393        0.113393
#
#       trend_lower  trend_upper  yhat_lower  yhat_upper    weekly  \
# 5236     9.636517     9.637372    6.602825   12.962054  0.113393
# 5237     9.636770     9.637958    6.327759   13.034110  0.113393
# ...

# %%
import pandas as pd
import numpy as np

a = pd.DataFrame(pd.date_range(start = '20160715',end = '20160716',freq = '20min'),columns=['time'])
a['week'] = a['time'].apply(lambda x: x.weekday())
a['time_window'] = a['time'].apply(lambda x:x.hour*3+x.minute/20)   
a['time'] = a['time'].apply(lambda x:x.strftime("%Y-%m-%d"))
a
# Out:
#           time  week  time_window
# 0   2016-07-15     4            0
# 1   2016-07-15     4            1
# 2   2016-07-15     4            2
# 3   2016-07-15     4            3
# 4   2016-07-15     4            4
# 5   2016-07-15     4            5
# 6   2016-07-15     4            6
# 7   2016-07-15     4            7
# 8   2016-07-15     4            8
# 9   2016-07-15     4            9
# 10  2016-07-15     4           10
# 11  2016-07-15     4           11
# 12  2016-07-15     4           12
# 13  2016-07-15     4           13
# 14  2016-07-15     4           14
# 15  2016-07-15     4           15
# 16  2016-07-15     4           16
# 17  2016-07-15     4           17
# 18  2016-07-15     4           18
# 19  2016-07-15     4           19
# 20  2016-07-15     4           20
# 21  2016-07-15     4           21
# 22  2016-07-15     4           22
# 23  2016-07-15     4           23
# 24  2016-07-15     4           24
# 25  2016-07-15     4           25
# ...
